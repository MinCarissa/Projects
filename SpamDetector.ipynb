# %%
import sys
import nltk
import sklearn
import pandas
import numpy
nltk.download('stopwords')


print('Python: {}'.format(sys.version))
print('NLTK: {}'.format(nltk.__version__))
print('Scikit-learn: {}'.format(sklearn.__version__))
print('Pandas: {}'.format(pandas.__version__))
print('Numpy: {}'.format(numpy.__version__))
# Out:
# Python: 2.7.16 |Anaconda, Inc.| (default, Mar 14 2019, 15:42:17) [MSC v.1500 64 bit (AMD64)]
# NLTK: 3.4
# Scikit-learn: 0.20.3
# Pandas: 0.24.2
# Numpy: 1.16.2
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %% [markdown]
# # 1. Load the Dataset

# %%
import pandas as pd
import numpy as np

# load the dataset of sms messages
df = pd.read_csv('SMSSpamCollection', header = None, encoding='utf-8', sep='\t')

# %%
# print useful information about the data set
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
# 0    5572 non-null object
# 1    5572 non-null object
# dtypes: object(2)
# memory usage: 87.1+ KB
# None
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# check class distribution
classes = df[0]
print(classes.value_counts())
# Out:
# ham     4825
# spam     747
# Name: 0, dtype: int64

# %% [markdown]
# # 2. Preprocess the Data

# %%
# convert class labels to binary values, 0 = ham, 1 = spam
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
Y = encoder.fit_transform(classes)

print(classes[:10])
print(Y[:10])
# Out:
# 0     ham
# 1     ham
# 2    spam
# 3     ham
# 4     ham
# 5    spam
# 6     ham
# 7     ham
# 8    spam
# 9    spam
# Name: 0, dtype: object
# [0 0 1 0 0 1 0 0 1 1]

# %%
# store the SMS message data
text_messages = df[1]
print(text_message[:10])
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# 5    FreeMsg Hey there darling it's been 3 week's n...
# 6    Even my brother is not like to speak with me. ...
# 7    As per your request 'Melle Melle (Oru Minnamin...
# 8    WINNER!! As a valued network customer you have...
# 9    Had your mobile 11 months or more? U R entitle...
# Name: 1, dtype: object

# %%
# use regular expressions to check email 
# replace email addresses with regex
processed = text_messages.str.replace(r'^.+@[^\.].*\.[a-z]{2,}$', 'emailaddr')

# replace urls with 'webaddress'
processed = processed.str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$', 'webaddress')

# replace money symboles with 'moneysymb'
processed = processed.str.replace(r'£|\$','moneysymb')

# replace 10 digit phone numbers with 'phonenumber'
processed = processed.str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$', 'phonenumber')
                                      
# replace normal numbers with 'number'
processed = processed.str.replace(r'\d+(\.\d+)?', 'number')

# %%
# remove punctuation
processed = processed.str.replace(r'[^\w\d\s]', '')

# replace whitespace
processed = processed.str.replace(r'\s+', ' ')

# remove leading and trailing whitespace
processed = processed.str.replace(r'^\s+|\s+?$', '')

# %%
# change words to lower case
processed = processed.str.lower()
print(processed)
# Out:
# 0       go until jurong point crazy available only in ...
# 1                                 ok lar joking wif u oni
# 2       free entry in number a wkly comp to win fa cup...
# 3             u dun say so early hor u c already then say
# 4       nah i dont think he goes to usf he lives aroun...
# 5       freemsg hey there darling its been number week...
# 6       even my brother is not like to speak with me t...
# 7       as per your request melle melle oru minnaminun...
# 8       winner as a valued network customer you have b...
# 9       had your mobile number months or more u r enti...
# 10      im gonna be home soon and i dont want to talk ...
# 11      six chances to win cash from number to numbern...
# 12      urgent you have won a number week free members...
# 13      ive been searching for the right words to than...
# 14                      i have a date on sunday with will
# 15      xxxmobilemovieclub to use your credit click th...
# 16                                   oh kim watching here
# 17      eh u remember how number spell his name yes i ...
# 18      fine if thats the way u feel thats the way its...
# 19      england v macedonia dont miss the goalsteam ne...
# 20               is that seriously how you spell his name
# 21      im going to try for number months ha ha only j...
# 22           so pay first lar then when is da stock comin
# 23      aft i finish my lunch then i go str down lor a...
# 24      ffffffffff alright no way i can meet up with y...
# 25      just forced myself to eat a slice im really no...
# 26                          lol your always so convincing
# 27      did you catch the bus are you frying an egg di...
# 28      im back amp were packing the car now ill let y...
# 29      ahhh work i vaguely remember that what does it...
#                               ...
# 5542             armand says get your ass over to epsilon
# 5543                u still havent got urself a jacket ah
# 5544    im taking derek amp taylor to walmart if im no...
# 5545        hi its in durban are you still on this number
# 5546             ic there are a lotta childporn cars then
# 5547    had your contract mobile number mnths latest m...
# 5548                     no i was trying it all weekend v
# 5549    you know wot people wear t shirts jumpers hat ...
# 5550            cool what time you think you can get here
# 5551    wen did you get so spiritual and deep thats great
# 5552    have a safe trip to nigeria wish you happiness...
# 5553                            hahahause your brain dear
# 5554    well keep in mind ive only got enough gas for ...
# 5555    yeh indians was nice tho it did kane me off a ...
# 5556    yes i have so thats why u texted pshewmissing ...
# 5557    no i meant the calculation is the same that lt...
# 5558                                 sorry ill call later
# 5559    if you arent here in the next ltgt hours imma ...
# 5560                      anything lor juz both of us lor
# 5561    get me out of this dump heap my mom decided to...
# 5562    ok lor sony ericsson salesman i ask shuhui the...
# 5563                              ard number like dat lor
# 5564    why dont you wait til at least wednesday to se...
# 5565                                            huh y lei
# 5566    reminder from onumber to get number pounds fre...
# 5567    this is the numbernd time we have tried number...
# 5568                    will b going to esplanade fr home
# 5569    pity was in mood for that soany other suggestions
# 5570    the guy did some bitching but i acted like id ...
# 5571                            rofl its true to its name
# Name: 1, Length: 5572, dtype: object

# %%
# remove stop words from text messages
#nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

processed = processed.apply(lambda x: ' '.join(term for term in x.split() if term not in stop_words))

# %%
# remove word stem using a Porter stemmer
ps = nltk.PorterStemmer()

processed = processed.apply(lambda x: ' '.join(ps.stem(term) for term in x.split()))

# %%
print(processed)
# Out:
# 0       go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif u oni
# 2       free entri number wkli comp win fa cup final t...
# 3                     u dun say earli hor u c alreadi say
# 4               nah dont think goe usf live around though
# 5       freemsg hey darl number week word back id like...
# 6           even brother like speak treat like aid patent
# 7       per request mell mell oru minnaminungint nurun...
# 8       winner valu network custom select receivea num...
# 9       mobil number month u r entitl updat latest col...
# 10      im gonna home soon dont want talk stuff anymor...
# 11      six chanc win cash number numbernumb pound txt...
# 12      urgent number week free membership numbernumb ...
# 13      ive search right word thank breather promi won...
# 14                                            date sunday
# 15      xxxmobilemovieclub use credit click wap link n...
# 16                                           oh kim watch
# 17      eh u rememb number spell name ye v naughti mak...
# 18                   fine that way u feel that way gota b
# 19      england v macedonia dont miss goalsteam news t...
# 20                                      seriou spell name
# 21                      im go tri number month ha ha joke
# 22                           pay first lar da stock comin
# 23      aft finish lunch go str lor ard number smth lo...
# 24                     ffffffffff alright way meet sooner
# 25      forc eat slice im realli hungri tho suck mark ...
# 26                                      lol alway convinc
# 27      catch bu fri egg make tea eat mom left dinner ...
# 28           im back amp pack car ill let know there room
# 29                    ahhh work vagu rememb feel like lol
#                               ...
# 5542                           armand say get ass epsilon
# 5543                  u still havent got urself jacket ah
# 5544    im take derek amp taylor walmart im back time ...
# 5545                               hi durban still number
# 5546                               ic lotta childporn car
# 5547    contract mobil number mnth latest motorola nok...
# 5548                                        tri weekend v
# 5549    know wot peopl wear shirt jumper hat belt know...
# 5550                                  cool time think get
# 5551                      wen get spiritu deep that great
# 5552    safe trip nigeria wish happi soon compani shar...
# 5553                                   hahahau brain dear
# 5554    well keep mind ive got enough ga one round tri...
# 5555    yeh indian nice tho kane bit shud go number dr...
# 5556                        ye that u text pshewmiss much
# 5557    meant calcul ltgt unit ltgt school realli expe...
# 5558                                 sorri ill call later
# 5559                  arent next ltgt hour imma flip shit
# 5560                                 anyth lor juz us lor
# 5561                get dump heap mom decid come low bore
# 5562    ok lor soni ericsson salesman ask shuhui say q...
# 5563                              ard number like dat lor
# 5564                dont wait til least wednesday see get
# 5565                                              huh lei
# 5566    remind onumb get number pound free call credit...
# 5567    numbernd time tri number contact u u number po...
# 5568                                b go esplanad fr home
# 5569                              piti mood soani suggest
# 5570    guy bitch act like id interest buy someth el n...
# 5571                                       rofl true name
# Name: 1, Length: 5572, dtype: object

# %%
from nltk.tokenize import word_tokenize

# creating a bag-of-words
all_words = []

for message in processed:
    words = word_tokenize(message)
    for w in words:
        all_words.append(w)
        
all_words = nltk.FreqDist(all_words)

# %%
print('Number of words: {}'.format(len(all_words)))
print('Most common words: {}'.format(all_words.most_common(15)))
# Out:
# Number of words: 7345
# Most common words: [(u'number', 2607), (u'u', 1132), (u'call', 655), (u'im', 474), (u'go', 452), (u'get', 446), (u'ur', 390), (u'come', 300), (u'dont', 298), (u'ok', 278), (u'ltgt', 276), (u'free', 275), (u'know', 270), (u'like', 257), (u'got', 251)]

# %%
word_features = list(all_words.keys())[:1500]

# %%
# define a find_features function
def find_features(message):
    words = word_tokenize(message)
    features =  {}
    for word in word_features:
        features[word] = (word in words)
    return features

features = find_features(processed[0])
for key, value in features.items():
    if value == True:
        print key
# Out:
# avail
# buffet
# world
# great

# %%
processed[0]
# Out:
# u'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
# find features for all messages
messages = zip(processed, Y)

seed = 1
np.random.seed = seed
np.random.shuffle(messages)
featuresets = [(find_features(text), label) for (text, label) in messages]

# %%
featuresets[0]
# Out:
# ({u'yellow': False,
#   u'elvi': False,
#   u'didntgiv': False,
#   u'captain': False,
#   u'lorw': False,
#   u'scold': False,
#   u'buddi': False,
#   u'lord': False,
#   u'numberpress': False,
#   u'digit': False,
#   u'callin': False,
#   u'claimcod': False,
#   u'gover': False,
#   u'sleepsweet': False,
#   u'appar': False,
#   u'oceand': False,
#   u'four': False,
#   u'disturb': False,
#   u'prize': False,
#   u'oficegot': False,
#   u'btnationalr': False,
#   u'wednesday': False,
#   u'somewheresomeon': False,
#   u'numbertxtnumberp': False,
#   u'oooh': False,
#   u'cheeto': False,
#   u'careswt': False,
#   u'nigh': False,
#   u'miller': False,
#   u'second': False,
#   u'titleso': False,
#   u'txtno': False,
#   u'dialogu': False,
#   u'wreck': False,
#   u'mondaynxt': False,
#   u'numberrespect': False,
#   u'maraikara': False,
#   u'uworld': False,
#   u'pooki': False,
#   u'med': False,
#   u'heri': False,
#   u'hero': False,
#   u'numbergot': False,
#   u'never': False,
#   u'dahe': False,
#   u'chine': False,
#   u'china': False,
#   u'dogwood': False,
#   u'dorm': False,
#   u'remet': False,
#   u'numberston': False,
#   u'strewn': False,
#   u'k': False,
#   u'spotti': False,
#   u'salesp': False,
#   u'jame': False,
#   u'jamsterget': False,
#   u'recpt': False,
#   u'drm': False,
#   u'fumbl': False,
#   u'golden': False,
#   u'youthat': False,
#   u'brought': False,
#   u'sterm': False,
#   u'sterl': False,
#   u'txt': False,
#   u'univ': False,
#   u'unit': False,
#   u'ithi': False,
#   u'spoke': False,
#   u'careabout': False,
#   u'thenwil': False,
#   u'dnt': False,
#   u'music': False,
#   u'chinchilla': False,
#   u'passport': False,
#   u'strike': False,
#   u'galsu': False,
#   u'supportprovid': False,
#   u'excu': False,
#   u'paperwork': False,
#   u'relax': False,
#   u'andrewsboy': False,
#   u'notif': False,
#   u'yahoo': False,
#   u'notic': False,
#   u'hurt': False,
#   u'glass': False,
#   u'gonumb': False,
#   u'holi': False,
#   u'hole': False,
#   u'hold': False,
#   u'tirupur': False,
#   u'accid': False,
#   u'yourinclu': False,
#   u'temal': False,
#   u'wwwregalportfoliocouk': False,
#   u'wenev': False,
#   u'wana': False,
#   u'drvgsto': False,
#   u'smth': False,
#   u'want': False,
#   u'wkentnumberpnumb': False,
#   u'hoo': False,
#   u'hol': False,
#   u'how': False,
#   u'hot': False,
#   u'hou': False,
#   u'hor': False,
#   u'hop': False,
#   u'scorabl': False,
#   u'perspect': False,
#   u'updat': False,
#   u'abdomen': False,
#   u'numberuz': False,
#   u'pimpl': False,
#   u'plyr': False,
#   u'swtheart': False,
#   u'lololo': False,
#   u'beauti': False,
#   u'bsnl': False,
#   u'numberui': False,
#   u'aroundn': False,
#   u'alian': False,
#   u'tulip': False,
#   u'yunni': False,
#   u'someplac': False,
#   u'wing': False,
#   u'wind': False,
#   u'wine': False,
#   u'oper': False,
#   u'callnumberoptoutyhl': False,
#   u'libertin': False,
#   u'murali': False,
#   u'surrend': False,
#   u'wud': False,
#   u'vari': False,
#   u'callcoz': False,
#   u'fit': False,
#   u'fix': False,
#   u'lovingli': False,
#   u'hidden': False,
#   u'easier': False,
#   u'messagestext': False,
#   u'duvet': False,
#   u'mtnl': False,
#   u'sensesrespect': False,
#   u'surgic': False,
#   u'gooddhanush': False,
#   u'silver': False,
#   u'rumour': False,
#   u'vivekanand': False,
#   u'dload': False,
#   u'websitenow': False,
#   u'accommod': False,
#   u'arrow': False,
#   u'volcano': False,
#   u'side': False,
#   u'bone': False,
#   u'luck': False,
#   u'burial': False,
#   u'resub': False,
#   u'fgkslpopw': False,
#   u'zaher': False,
#   u'allah': False,
#   u'dodda': False,
#   u'numbernumberthousadi': False,
#   u'doug': False,
#   u'petrolr': False,
#   u'ru': False,
#   u'rv': False,
#   u'rr': False,
#   u'rs': False,
#   u'rd': False,
#   u'neft': False,
#   u'ra': False,
#   u'ro': False,
#   u'linear': False,
#   u'navig': False,
#   u'dracula': False,
#   u'fave': False,
#   u'fassyol': False,
#   u'muchxxlov': False,
#   u'homewot': False,
#   u'ate': False,
#   u'dearlov': False,
#   u'atm': False,
#   u'correctionor': False,
#   u'unabl': False,
#   u'vijay': False,
#   u'bite': False,
#   u'itleav': False,
#   u'wast': False,
#   u'instruct': False,
#   u'kfc': False,
#   u'massiv': False,
#   u'youso': False,
#   u'xin': False,
#   u'wedlunch': False,
#   u'master': False,
#   u'studdi': False,
#   u'hiya': False,
#   u'listen': False,
#   u'termsappli': False,
#   u'wisdom': False,
#   u'technic': False,
#   u'trek': False,
#   u'peril': False,
#   u'saeed': False,
#   u'tree': False,
#   u'shower': False,
#   u'unint': False,
#   u'callnumberoptoutnumb': False,
#   u'boston': False,
#   u'mycallsu': False,
#   u'wktxt': False,
#   u'reassur': False,
#   u'increment': False,
#   u'hunnyhop': False,
#   u'seek': False,
#   u'dozen': False,
#   u'person': False,
#   u'witot': False,
#   u'numbertctxt': False,
#   u'shall': False,
#   u'doin': False,
#   u'object': False,
#   u'nightnobodi': False,
#   u'victoria': False,
#   u'mouth': False,
#   u'addict': False,
#   u'letter': False,
#   u'thriller': False,
#   u'zealand': False,
#   u'professor': False,
#   u'camp': False,
#   u'hospit': False,
#   u'tech': False,
#   u'neekunna': False,
#   u'diskyou': False,
#   u'scream': False,
#   u'came': False,
#   u'marvel': False,
#   u'wikipediacom': False,
#   u'bomb': False,
#   u'messageit': False,
#   u'teresa': False,
#   u'prix': False,
#   u'buzzzz': False,
#   u'themp': False,
#   u'menu': False,
#   u'restaur': False,
#   u'sfrom': False,
#   u'theme': False,
#   u'busi': False,
#   u'rich': False,
#   u'mene': False,
#   u'rice': False,
#   u'buse': False,
#   u'plate': False,
#   u'colourredtextcolourtxtstar': False,
#   u'ceil': False,
#   u'pocket': False,
#   u'giggl': False,
#   u'ambrithmaduraimet': False,
#   u'remembr': False,
#   u'trebl': False,
#   u'piggi': False,
#   u'boxnumbercnumberpm': False,
#   u'kalli': False,
#   u'greeni': False,
#   u'respond': False,
#   u'fair': False,
#   u'numberstop': False,
#   u'rupaul': False,
#   u'strongbuy': False,
#   u'goodnight': False,
#   u'result': False,
#   u'fail': False,
#   u'bleh': False,
#   u'best': False,
#   u'lotz': False,
#   u'onedg': False,
#   u'ctargg': False,
#   u'lotr': False,
#   u'havebeen': False,
#   u'figur': False,
#   u'cutefrnd': False,
#   u'thesmszonecom': False,
#   u'validnumberhr': False,
#   u'glasgow': False,
#   u'rajini': False,
#   u'packalso': False,
#   u'wtc': False,
#   u'freemessag': False,
#   u'wtf': False,
#   u'wth': False,
#   u'toler': False,
#   u'roller': False,
#   u'unemploy': False,
#   u'soonlot': False,
#   u'macedonia': False,
#   u'piti': False,
#   u'lookin': False,
#   u'tomarrow': False,
#   u'machan': False,
#   u'countri': False,
#   u'login': False,
#   u'timehop': False,
#   u'happenin': False,
#   u'darlin': False,
#   u'diff': False,
#   u'assum': False,
#   u'question': False,
#   u'fri': False,
#   u'fro': False,
#   u'frm': False,
#   u'much': False,
#   u'wuld': False,
#   u'stadium': False,
#   u'hesit': False,
#   u'life': False,
#   u'moneya': False,
#   u'moneyi': False,
#   u'athom': False,
#   u'dave': False,
#   u'lift': False,
#   u'spif': False,
#   u'chile': False,
#   u'child': False,
#   u'spin': False,
#   u'chill': False,
#   u'unsold': False,
#   u'commerci': False,
#   u'employ': False,
#   u'maneg': False,
#   u'meetin': False,
#   u'marriag': False,
#   u'kidz': False,
#   u'alritehav': False,
#   u'nofew': False,
#   u'player': False,
#   u'snumber': False,
#   u'siri': False,
#   u'honi': False,
#   u'tgxxrz': False,
#   u'dha': False,
#   u'hont': False,
#   u'habbahw': False,
#   u'split': False,
#   u'jungl': False,
#   u'costum': False,
#   u'youdearwith': False,
#   u'shja': False,
#   u'refil': False,
#   u'aeroplan': False,
#   u'tune': False,
#   u'tund': False,
#   u'numberish': False,
#   u'bewar': False,
#   u'xxxxxxxxxxxxxx': False,
#   u'gigolo': False,
#   u'wahe': False,
#   u'nydc': False,
#   u'ucal': False,
#   u'waht': False,
#   u'wwwbnumberutelecom': False,
#   u'hai': False,
#   u'ham': False,
#   u'easi': False,
#   u'loveabl': False,
#   u'haf': False,
#   u'recdthirtyeight': False,
#   u'lttimegt': False,
#   u'numberwp': False,
#   u'numberwq': False,
#   u'hat': False,
#   u'hav': False,
#   u'numberwu': False,
#   u'numberhousemaid': False,
#   u'birth': False,
#   u'shadow': False,
#   u'measur': False,
#   u'careumma': False,
#   u'specif': False,
#   u'remind': False,
#   u'ola': False,
#   u'right': False,
#   u'old': False,
#   u'crowd': False,
#   u'processnetwork': False,
#   u'fuuuuck': False,
#   u'creep': False,
#   u'bottom': False,
#   u'fox': False,
#   u'condit': False,
#   u'muhommad': False,
#   u'wocay': False,
#   u'sensibl': False,
#   u'dental': False,
#   u'colleg': False,
#   u'adew': False,
#   u'numberlov': False,
#   u'babesozi': False,
#   u'slightli': False,
#   u'bandag': False,
#   u'soc': False,
#   u'honeymoon': False,
#   u'sol': False,
#   u'soo': False,
#   u'creativ': False,
#   u'soz': False,
#   u'waitu': False,
#   u'smsservic': False,
#   u'janx': False,
#   u'suffici': False,
#   u'support': False,
#   u'happi': False,
#   u'avail': False,
#   u'acknowledg': False,
#   u'jane': False,
#   u'constantli': False,
#   u'waiti': False,
#   u'headach': False,
#   u'offer': False,
#   u'paypal': False,
#   u'onluy': False,
#   u'onlybettr': False,
#   u'offen': False,
#   u'callnumberoptoutj': False,
#   u'layin': False,
#   u'chargednumberpmsgnumb': False,
#   u'pest': False,
#   u'comingtmorow': False,
#   u'wyli': False,
#   u'wwwwinnumbercouk': False,
#   u'numberoff': False,
#   u'rajnik': False,
#   u'textbook': False,
#   u'exist': False,
#   u'ericsson': False,
#   u'dealer': False,
#   u'floor': False,
#   u'ofnumb': False,
#   u'tip': False,
#   u'actor': False,
#   u'flood': False,
#   u'role': False,
#   u'mpnumber': False,
#   u'smell': False,
#   u'roll': False,
#   u'youani': False,
#   u'relat': False,
#   u'intend': False,
#   u'fathima': False,
#   u'numbertulsi': False,
#   u'intent': False,
#   u'wwwdbuknet': False,
#   u'nowstil': False,
#   u'nxt': False,
#   u'time': False,
#   u'push': False,
#   u'timi': False,
#   u'sday': False,
#   u'chain': False,
#   u'saibaba': False,
#   u'cudnt': False,
#   u'oso': False,
#   u'okor': False,
#   u'decid': False,
#   u'baller': False,
#   u'youphon': False,
#   u'overdid': False,
#   u'decim': False,
#   u'alrit': False,
#   u'subtoitl': False,
#   u'macha': False,
#   u'okok': False,
#   u'followin': False,
#   u'macho': False,
#   u'normnumberpton': False,
#   u'boxnumberqu': False,
#   u'jeri': False,
#   u'prepaid': False,
#   u'doke': False,
#   u'personmeet': False,
#   u'exact': False,
#   u'tear': False,
#   u'leftov': False,
#   u'kalstiyathen': False,
#   u'pretsovru': False,
#   u'team': False,
#   u'cooki': False,
#   u'prevent': False,
#   u'numberonli': False,
#   u'blackand': False,
#   u'videochat': False,
#   u'unmit': False,
#   u'sigh': False,
#   u'sign': False,
#   u'prizeto': False,
#   u'rentl': False,
#   u'workand': False,
#   u'ba': False,
#   u'headset': False,
#   u'freaki': False,
#   u'dateboxnumberessexcmnumberxn': False,
#   u'melt': False,
#   u'current': False,
#   u'shitjustfound': False,
#   u'mell': False,
#   u'thecd': False,
#   u'boost': False,
#   u'slot': False,
#   u'woot': False,
#   u'address': False,
#   u'galileo': False,
#   u'along': False,
#   u'yetti': False,
#   u'brilliant': False,
#   u'influx': False,
#   u'love': False,
#   u'prefer': False,
#   u'fake': False,
#   u'instal': False,
#   u'bloodi': False,
#   u'httpwwwurawinnercom': False,
#   u'wicket': False,
#   u'angri': False,
#   u'tightli': False,
#   u'afford': False,
#   u'peopl': False,
#   u'cshnumber': False,
#   u'ooooooh': False,
#   u'appendix': False,
#   u'easiest': False,
#   u'behalf': False,
#   u'logop': False,
#   u'numberneighbour': False,
#   u'hussey': False,
#   u'pretend': False,
#   u'vega': False,
#   u'whatev': False,
#   u'knowwait': False,
#   u'jamstercouk': False,
#   u'logon': False,
#   u'problemat': False,
#   u'usno': False,
#   u'recycl': False,
#   u'minstext': False,
#   u'akonlon': False,
#   u'immuni': False,
#   u'unredeem': False,
#   u'lido': False,
#   u'datz': False,
#   u'filthi': False,
#   u'spou': False,
#   u'monkeespeopl': False,
#   u'prabhaim': False,
#   u'date': False,
#   u'suck': False,
#   u'data': False,
#   u'brainless': False,
#   u'stress': False,
#   u'satlov': False,
#   u'sr': False,
#   u'sp': False,
#   u'st': False,
#   u'blastin': False,
#   u'hon': False,
#   u'si': False,
#   u'sh': False,
#   u'truck': False,
#   u'sn': False,
#   u'sm': False,
#   u'swollen': False,
#   u'sc': False,
#   u'liaotoo': False,
#   u'travel': False,
#   u'se': False,
#   u'sd': True,
#   u'drunken': False,
#   u'vaazhthukk': False,
#   u'speedchat': False,
#   u'elain': False,
#   u'konw': False,
#   u'disconnect': False,
#   u'fixedlin': False,
#   u'avin': False,
#   u'instantli': False,
#   u'jiu': False,
#   u'fastpl': False,
#   u'rounderso': False,
#   u'smarter': False,
#   u'nation': False,
#   u'somenumb': False,
#   u'twilight': False,
#   u'pokkiri': False,
#   u'uawakefeellikw': False,
#   u'itsnot': False,
#   u'didt': False,
#   u'guoyang': False,
#   u'receipt': False,
#   u'borrow': False,
#   u'sponsor': False,
#   u'pataistha': False,
#   u'alwi': False,
#   u'numberyf': False,
#   u'blu': False,
#   u'alwa': False,
#   u'frontiervil': False,
#   u'missunderstd': False,
#   u'numberyr': False,
#   u'trauma': False,
#   u'internet': False,
#   u'darlinim': False,
#   u'hcl': False,
#   u'bcmsfwcnumbernnumberxx': False,
#   u'sheffield': False,
#   u'million': False,
#   u'envelop': False,
#   u'codenumberxxnumb': False,
#   u'plea': False,
#   u'grandma': False,
#   u'vijaykanth': False,
#   u'downon': False,
#   u'rael': False,
#   u'dunno': False,
#   u'numbernumbermp': False,
#   u'kkwhere': False,
#   u'yun': False,
#   u'hooch': False,
#   u'neglect': False,
#   u'itnow': False,
#   u'oni': False,
#   u'frwd': False,
#   u'spoken': False,
#   u'muchi': False,
#   u'gudnitetcpract': False,
#   u'potter': False,
#   u'beverag': False,
#   u'one': False,
#   u'nattil': False,
#   u'marri': False,
#   u'spanish': False,
#   u'vava': False,
#   u'drove': False,
#   u'open': False,
#   u'unrecogn': False,
#   u'urin': False,
#   u'christmasmerri': False,
#   u'christma': False,
#   u'definitli': False,
#   u'caught': False,
#   u'citi': False,
#   u'fml': False,
#   u'walik': False,
#   u'numberbold': False,
#   u'conveni': False,
#   u'msgnumberrcvd': False,
#   u'officethenampet': False,
#   u'that': False,
#   u'provinc': False,
#   u'season': False,
#   u'callsnumberminmobsmor': False,
#   u'snatch': False,
#   u'floppi': False,
#   u'boyfriend': False,
#   u'weddingfriend': False,
#   u'breadstick': False,
#   u'applespairs': False,
#   u'dontnumbergetnumbertext': False,
#   u'arun': False,
#   u'arul': False,
#   u'wwwgambtv': False,
#   u'prospect': False,
#   u'sao': False,
#   u'mindsetbeliev': False,
#   u'thepub': False,
#   u'argument': False,
#   u'sae': False,
#   u'sad': False,
#   u'woah': False,
#   u'say': False,
#   u'fiendmak': False,
#   u'numberchildren': False,
#   u'sar': False,
#   u'saw': False,
#   u'sat': False,
#   u'bootyd': False,
#   u'zoe': False,
#   u'disturbancemight': False,
#   u'goodmat': False,
#   u'aproach': False,
#   u'note': False,
#   u'taka': False,
#   u'take': False,
#   u'ericson': False,
#   u'noth': False,
#   u'printer': False,
#   u'anythi': False,
#   u'knew': False,
#   u'buffet': False,
#   u'knee': False,
#   u'sall': False,
#   u'phil': False,
#   u'sale': False,
#   u'wherebtw': False,
#   u'urmomi': False,
#   u'mre': False,
#   u'numbershi': False,
#   u'axi': False,
#   u'salt': False,
#   u'numbereva': False,
#   u'raja': False,
#   u'evng': False,
#   u'bright': False,
#   u'ground': False,
#   u'aint': False,
#   u'slow': False,
#   u'transact': False,
#   u'activ': False,
#   u'xma': False,
#   u'foward': False,
#   u'jaykwon': False,
#   u'actin': False,
#   u'hockey': False,
#   u'slob': False,
#   u'pressi': False,
#   u'numbersomenumb': False,
#   u'psychiatrist': False,
#   u'champlaxig': False,
#   u'kickoff': False,
#   u'misundrstud': False,
#   u'requir': False,
#   u'upnot': False,
#   u'artist': False,
#   u'getstop': False,
#   u'cumin': False,
#   u'aptitud': False,
#   u'racal': False,
#   u'twelv': False,
#   u'roger': False,
#   u'aclnumberpm': False,
#   u'tortilla': False,
#   u'where': False,
#   u'swnumber': False,
#   u'aslamalaikkuminsha': False,
#   u'up': False,
#   u'dormitori': False,
#   u'um': False,
#   u'cttargg': False,
#   u'wellyou': False,
#   u'availa': False,
#   u'olayiwola': False,
#   u'jumper': False,
#   u'dinero': False,
#   u'screen': False,
#   u'punto': False,
#   u'spare': False,
#   u'upcharg': False,
#   u'shracomorsglsupltnumb': False,
#   u'shortag': False,
#   u'spark': False,
#   u'numberpday': False,
#   u'beliv': False,
#   u'shindig': False,
#   u'gwr': False,
#   u'mani': False,
#   u'ukpnumb': False,
#   u'panick': False,
#   u'everynumb': False,
#   u'twin': False,
#   u'anti': False,
#   u'ortxt': False,
#   u'boat': False,
#   u'welltak': False,
#   u'stretch': False,
#   u'west': False,
#   u'breath': False,
#   u'numberkbsubject': False,
#   u'reflex': False,
#   u'gist': False,
#   u'hlday': False,
#   u'thousand': False,
#   u'resolut': False,
#   u'thoso': False,
#   u'iscom': False,
#   u'freephon': False,
#   u'shopw': False,
#   u'ive': False,
#   u'thatll': False,
#   u'brow': False,
#   u'masteriast': False,
#   u'convinc': False,
#   u'bian': False,
#   u'blah': False,
#   u'pinku': False,
#   u'hyperten': False,
#   u'thinkin': False,
#   u'nighter': False,
#   u'carewhoev': False,
#   u'askin': False,
#   u'dontplea': False,
#   u'cheeri': False,
#   u'carso': False,
#   u'ignumb': False,
#   u'callon': False,
#   u'footprint': False,
#   u'defo': False,
#   u'costa': False,
#   u'nowadayslot': False,
#   u'burrito': False,
#   u'knicker': False,
#   u'geniu': False,
#   u'grumpi': False,
#   u'hubbi': False,
#   u'nothin': False,
#   u'itmail': False,
#   u'summer': False,
#   u'numberunumb': False,
#   u'numberterror': False,
#   u'forevr': False,
#   u'rest': False,
#   u'weekli': False,
#   u'sorryi': False,
#   u'ghodbandar': False,
#   u'concentr': False,
#   u'workag': False,
#   u'hint': False,
#   u'littl': False,
#   u'kerala': False,
#   u'real': False,
#   u'amk': False,
#   u'proze': False,
#   u'around': False,
#   u'enumb': False,
#   u'landlin': False,
#   u'dark': False,
#   u'traffic': False,
#   u'darl': False,
#   u'world': False,
#   u'lnli': False,
#   u'dare': False,
#   u'costnumberpm': False,
#   u'stranger': False,
#   u'quizclub': False,
#   u'tsunami': False,
#   u'nytecnumberanumberlpmsgnumberp': False,
#   u'manag': False,
#   u'gimmi': False,
#   u'pdate_now': False,
#   u'mapquest': False,
#   u'prashanthettan': False,
#   u'playin': False,
#   u'aust': False,
#   u'tote': False,
#   u'noon': False,
#   u'definit': False,
#   u'numberpol': False,
#   u'evapor': False,
#   u'numbercustcar': False,
#   u'comingdown': False,
#   u'power': False,
#   u'fishrman': False,
#   u'yetund': False,
#   u'earthsofa': False,
#   u'leadership': False,
#   u'alaipayuth': False,
#   u'acc': False,
#   u'stone': False,
#   u'comfey': False,
#   u'chikkuali': False,
#   u'ach': False,
#   u'luci': False,
#   u'numberwhen': False,
#   u'neighbor': False,
#   u'act': False,
#   u'waheeda': False,
#   u'effici': False,
#   u'charli': False,
#   u'hep': False,
#   u'ertini': False,
#   u'moneysymbnumberpax': False,
#   u'hex': False,
#   u'hey': False,
#   u'invnt': False,
#   u'hee': False,
#   u'resum': False,
#   u'hen': False,
#   u'namenumb': False,
#   u'tellmiss': False,
#   u'misss': False,
#   u'bottl': False,
#   u'worriedx': False,
#   u'bundl': False,
#   u'hairdress': False,
#   u'spider': False,
#   u'congratul': False,
#   u'treacl': False,
#   u'numbercup': False,
#   u'pull': False,
#   u'rush': False,
#   u'chatnumb': False,
#   u'dirti': False,
#   u'xxxxxxx': False,
#   u'flirt': False,
#   u'darker': False,
#   u'aa': False,
#   u'gone': False,
#   u'ac': False,
#   u'ab': False,
#   u'gona': False,
#   u'ag': False,
#   u'uif': False,
#   u'mundh': False,
#   u'ak': False,
#   u'am': False,
#   u'al': False,
#   u'browsin': False,
#   u'kuch': False,
#   u'tshirt': False,
#   u'ar': False,
#   u'av': False,
#   u'ay': False,
#   u'ax': False,
#   u'tranquil': False,
#   u'cream': False,
#   u'yoga': False,
#   u'googl': False,
#   u'puppi': False,
#   u'tight': False,
#   u'yummmm': False,
#   u'sculptur': False,
#   u'tiwari': False,
#   u'terri': False,
#   u'openin': False,
#   u'closebi': False,
#   u'eruku': False,
#   u'asapok': False,
#   u'mask': False,
#   u'agr': False,
#   u'groov': False,
#   u'daysso': False,
#   u'adam': False,
#   u'norcorp': False,
#   u'insha': False,
#   u'sch': False,
#   u'hgsuitenumbernumberland': False,
#   u'bridgwat': False,
#   u'tv': False,
#   u'tt': False,
#   u'ts': False,
#   u'tp': False,
#   u'hillsborough': False,
#   u'nora': False,
#   u'tm': False,
#   u'th': False,
#   u'legitimat': False,
#   u'smile': False,
#   u'tb': False,
#   u'tc': False,
#   u'norm': False,
#   u'ta': True,
#   u'mufti': False,
#   u'pple': False,
#   u'perumbavoor': False,
#   u'checkin': False,
#   u'colani': False,
#   u'fuckinniceselfishdeviousbitchanywayil': False,
#   u'strang': False,
#   u'peski': False,
#   u'harri': False,
#   u'colleagu': False,
#   u'skillgamenumberwinaweek': False,
#   u'dodgey': False,
#   u'sang': False,
#   u'adjust': False,
#   u'small': False,
#   u'tddnewsletteremcnumbercouk': False,
#   u'hict': False,
#   u'pase': False,
#   u'readyal': False,
#   u'sync': False,
#   u'past': False,
#   u'sandiago': False,
#   u'notixiqu': False,
#   u'pass': False,
#   u'healer': False,
#   u'riddanc': False,
#   u'clock': False,
#   u'mobileupdnumb': False,
#   u'section': False,
#   u'panalambut': False,
#   u'delet': False,
#   u'method': False,
#   u'burgundi': False,
#   u'full': False,
#   u'sarasota': False,
#   u'tiim': False,
#   ...},
#  0)

# %%
# split training and testing data sets using sklearn
from sklearn import model_selection
training, testing = model_selection.train_test_split(featuresets, test_size = 0.25, random_state = seed)

# %%
print('Training:{}'.format(len(training))
print('Testing:{}'.format(len(testing)))
# Out:
# Training:4179
# Testing:1393

# %% [markdown]
# # 4. Scikit-learn classifier with NLTK

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Define models to train
names = ['K Nearest Neighbors', 'Decision Tree', 'Random Forest', 'Logistic Regression', 'SGD Classifier', 'Naive Bayes', 'SVM Linear']

classifiers = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    SGDClassifier(max_iter = 100),
    MultinomialNB(),
    SVC(kernel = 'linear')
]

models = zip(names, classifiers)

# %%
from nltk.classify.scikitlearn import SklearnClassifier

for name, model in models:
    nltk_model = SklearnClassifier(model)
    nltk_model.train(training)
    accuray = nltk.classify.accuracy(nltk_model, testing) * 100
    print('{} accuray: {}'.format(name, accuray))
# Out:
# K Nearest Neighbors accuray: 92.9648241206
# Decision Tree accuray: 94.9030868629
# Random Forest accuray: 95.6927494616
# Logistic Regression accuray: 95.9798994975
# SGD Classifier accuray: 95.7645369706
# Naive Bayes accuray: 95.0466618808
# SVM Linear accuray: 95.4055994257

# %%
# ensemble learning - voting classifier
from sklearn.ensemble import VotingClassifier

# Define models to train
names = ['K Nearest Neighbors', 'Decision Tree', 'Random Forest', 'Logistic Regression', 'SGD Classifier', 'Naive Bayes', 'SVM Linear']

classifiers = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    SGDClassifier(max_iter = 100),
    MultinomialNB(),
    SVC(kernel = 'linear')
]

models = zip(names, classifiers)

nltk_ensemble = SklearnClassifier(VotingClassifier(estimators = models, voting='hard',  n_jobs = -1))
nltk_ensemble.train(training)
accuray = nltk.classify.accuracy(nltk_ensemble, testing) * 100
print('Ensemble classifier accuray: {}'.format(accuray))
# Out:
# Ensemble classifier accuray: 96.0516870065

# %%
# predict test data label
txt_features, labels = zip(*testing)
prediction = nltk_ensemble.classify_many(txt_features)

# %%
print(classification_report(labels, prediction))
pd.DataFrame(
    confusion_matrix(labels, prediction),
    index = [['actual', 'actual'], ['ham', 'spam']],
    columns = [['predicted', 'predicted'], ['ham', 'spam']]
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1208
#            1       0.94      0.75      0.83       185
#
#    micro avg       0.96      0.96      0.96      1393
#    macro avg       0.95      0.87      0.91      1393
# weighted avg       0.96      0.96      0.96      1393
#             predicted
#                   ham spam
# actual ham       1199    9
#        spam        46  139
